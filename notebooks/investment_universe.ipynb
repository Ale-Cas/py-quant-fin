# %%
# %load_ext autoreload
# %autoreload 2

# %%
from quantfin.market.investment_universe import InvestmentUniverse
import yfinance as yf

# %%
import yfinance as yf
yf.Ticker("AAPL").history()
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 2021-12-27  177.089996  180.419998  177.070007  180.330002   74919600
# 2021-12-28  180.160004  181.330002  178.529999  179.289993   79144300
# 2021-12-29  179.330002  180.630005  178.139999  179.380005   62348900
# 2021-12-30  179.470001  180.570007  178.089996  178.199997   59773000
# 2021-12-31  178.089996  179.229996  177.259995  177.570007   64062300
# 2022-01-03  177.830002  182.880005  177.710007  182.009995  104487900
# 2022-01-04  182.630005  182.940002  179.119995  179.699997   99310400
# 2022-01-05  179.610001  180.169998  174.639999  174.919998   94537600
# 2022-01-06  172.699997  175.300003  171.639999  172.000000   96904000
# 2022-01-07  172.889999  174.139999  171.029999  172.169998   86580100
# 2022-01-10  169.080002  172.500000  168.169998  172.190002  106765600
# 2022-01-11  172.320007  175.179993  170.820007  175.080002   76138300
# ...

# %%
nas = InvestmentUniverse(name = "NASDAQ 100")
yf.download(tickers=[str(asset) for asset in nas.assets])
# Out:
# [*********************100%***********************]  101 of 101 completed
#              Adj Close                                                  \
#                   AAPL        ABNB        ADBE         ADI         ADP
# Date
# 1962-01-02         NaN         NaN         NaN         NaN         NaN
# 1962-01-03         NaN         NaN         NaN         NaN         NaN
# 1962-01-04         NaN         NaN         NaN         NaN         NaN
# 1962-01-05         NaN         NaN         NaN         NaN         NaN
# 1962-01-08         NaN         NaN         NaN         NaN         NaN
# ...                ...         ...         ...         ...         ...
# 2022-01-19  166.229996  154.580002  516.580017  163.059998  224.830002
# 2022-01-20  164.509995  158.000000  510.850006  158.630005  220.309998
# 2022-01-21  162.410004  156.729996  499.910004  159.520004  217.130005
# 2022-01-24  161.619995  147.899994  519.659973  161.440002  218.240005
# ...

# %%
nas = InvestmentUniverse(name = "NASDAQ 100")
[asset for asset in nas.assets]
# Out:
# [MAR,
#  VRTX,
#  AEP,
#  ODFL,
#  AMGN,
#  ADI,
#  VRSN,
#  KLAC,
#  LCID,
#  SPLK,
#  AMD,
#  EA,
#  NTES,
#  HON,
#  GILD,
#  DLTR,
#  SWKS,
#  KHC,
#  ADBE,
#  CSX,
#  MELI,
#  DXCM,
#  CSCO,
#  AMAT,
#  TSLA,
#  LULU,
#  PEP,
#  SGEN,
#  MU,
#  MDLZ,
#  AMZN,
#  ILMN,
#  PANW,
#  MNST,
#  PCAR,
#  TMUS,
#  CPRT,
#  INTC,
#  PYPL,
#  DOCU,
#  SBUX,
#  ANSS,
#  NFLX,
#  WBA,
#  AAPL,
#  INTU,
#  ALGN,
#  ASML,
#  ISRG,
#  CMCSA,
#  MSFT,
#  NVDA,
#  PAYX,
#  QCOM,
#  EXC,
#  KDP,
#  ADSK,
#  TXN,
#  MTCH,
#  XEL,
#  CDNS,
#  LRCX,
#  IDXX,
#  NXPI,
#  ATVI,
#  ABNB,
#  ADP,
#  MCHP,
#  DDOG,
#  XLNX,
#  BIIB,
#  AVGO,
#  MRNA,
#  SIRI,
#  FTNT,
#  SNPS,
#  CHTR,
#  REGN,
#  ZS,
#  CRWD,
#  PDD,
#  MRVL,
#  ROST,
#  COST,
#  FISV,
#  VRSK,
#  FB,
#  ZM,
#  JD,
#  EBAY,
#  BIDU,
#  FAST,
#  BKNG,
#  TEAM,
#  ORLY,
#  CTAS,
#  GOOG,
#  CTSH,
#  WDAY,
#  OKTA,
#  GOOGL]

# %%
nas = InvestmentUniverse(name = "NASDAQ 100")
nas_prices = nas.get_prices()
# Out:
# Exception in thread Thread-7:
# Traceback (most recent call last):
#   File "C:\Users\castr\AppData\Local\Programs\Python\Python39\lib\threading.py", line 973, in _bootstrap_inner
#     self.run()
#   File "C:\Users\castr\AppData\Local\Programs\Python\Python39\lib\threading.py", line 910, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\castr\AppData\Local\pypoetry\Cache\virtualenvs\py-quant-fin-d8An81W4-py3.9\lib\site-packages\multitasking\__init__.py", line 104, in _run_via_pool
#     return callee(*args, **kwargs)
#   File "C:\Users\castr\AppData\Local\pypoetry\Cache\virtualenvs\py-quant-fin-d8An81W4-py3.9\lib\site-packages\yfinance\multi.py", line 188, in _download_one_threaded
#     data = _download_one(ticker, start, end, auto_adjust, back_adjust,
#   File "C:\Users\castr\AppData\Local\pypoetry\Cache\virtualenvs\py-quant-fin-d8An81W4-py3.9\lib\site-packages\yfinance\multi.py", line 202, in _download_one
# ...

# %%
nas.prices
# Out:
#                   DDOG                                                 \
#                   Open        High         Low       Close     Volume
# Date
# 1962-01-02         NaN         NaN         NaN         NaN        NaN
# 1962-01-03         NaN         NaN         NaN         NaN        NaN
# 1962-01-04         NaN         NaN         NaN         NaN        NaN
# 1962-01-05         NaN         NaN         NaN         NaN        NaN
# 1962-01-08         NaN         NaN         NaN         NaN        NaN
# ...                ...         ...         ...         ...        ...
# 2022-01-05  152.449997  154.500000  144.729996  145.520004  7248100.0
# 2022-01-06  145.688995  151.339996  142.580002  143.889999  5939600.0
# 2022-01-07  144.000000  148.589996  140.589996  143.789993  2551800.0
# 2022-01-10  139.779999  146.520004  134.169998  146.330002  4952700.0
# 2022-01-11  144.800003  150.119995  143.500000  147.570007  1791615.0
#
# ...

# %%
sp = InvestmentUniverse(name = "SP500")
sp.get_prices()
# Out:
# [*********************100%***********************]  505 of 505 completed
#
# 2 Failed downloads:
# - BRK.B: No data found, symbol may be delisted
# - BF.B: None
#                   QCOM                                                  \
#                   Open        High         Low       Close   Adj Close
# Date
# 1962-01-02         NaN         NaN         NaN         NaN         NaN
# 1962-01-03         NaN         NaN         NaN         NaN         NaN
# 1962-01-04         NaN         NaN         NaN         NaN         NaN
# 1962-01-05         NaN         NaN         NaN         NaN         NaN
# 1962-01-08         NaN         NaN         NaN         NaN         NaN
# ...                ...         ...         ...         ...         ...
# 2022-01-04  187.000000  188.929993  181.009995  187.229996  187.229996
# 2022-01-05  186.500000  193.580002  184.729996  186.500000  186.500000
# 2022-01-06  184.520004  188.470001  183.000000  185.949997  185.949997
# ...
